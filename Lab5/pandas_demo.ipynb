# %% [markdown]
# # Pandas simplest demo
#
#
# Hint: run cell: Shift+Enter

# %%
import pandas as pd

# %%
# Create a DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'London', 'Paris']
}
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30    London
# 2  Charlie   35     Paris

# %%
df['Age']
# Out:
# 0    25
# 1    30
# 2    35
# Name: Age, dtype: int64

# %%
print(df['Age'].mean())
# Out:
# 30.0

# %%
# Select people older than 28
older_than_28 = df[df['Age'] > 28]
older_than_28
# Out:
#       Name  Age    City
# 1      Bob   30  London
# 2  Charlie   35   Paris

# %%
df
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30    London
# 2  Charlie   35     Paris

# %%
df['Age']
# Out:
# 0    25
# 1    30
# 2    35
# Name: Age, dtype: int64

# %%
df['Age'] > 28
# Out:
# 0    False
# 1     True
# 2     True
# Name: Age, dtype: bool

# %%
df[df['Age'] > 28]
# Out:
#       Name  Age    City
# 1      Bob   30  London
# 2  Charlie   35   Paris
